# %% [markdown]
# <a href="https://colab.research.google.com/github/king-dareels/Hamoye/blob/main/Hamoye_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv"
food_data = pd.read_csv (url, encoding = "latin-1")
food_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_data_grouped = food_data.groupby('Y2017')['Area'].sum()
food_data_grouped.groupby('Y2017').max()
# Out:
# Y2017
# -1582.0                       EgyptEgypt
# -1200.0                       Mozambique
# -1159.0                       Mozambique
# -865.0       United Republic of Tanzania
# -860.0       United Republic of Tanzania
#                         ...
#  96443.0                           Egypt
#  106400.0                       Ethiopia
#  112625.0                        Nigeria
#  117702.0                        Nigeria
#  190873.0                        Nigeria
# Name: Area, Length: 4537, dtype: object

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
food_data.groupby('Item')[2015, 2018].sum()
# Out:
# <ipython-input-28-73ecd32d7d66>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data.groupby('Item')[2015, 2018].sum()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-73ecd32d7d66> in <cell line: 1>()
# ----> 1 food_data.groupby('Item')[2015, 2018].sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     236             if len(self.obj.columns.intersection(key)) != len(set(key)):
# ...
